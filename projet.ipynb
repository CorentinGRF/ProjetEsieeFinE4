# %%
 # %run test.py
# Out:
# step : 0
# {'remainingOverageTime': 60, 'step': 1, 'geese': [[50], [19], [27], [69]], 'food': [59, 28], 'index': 0}
# 201
# False
# {}
# step : 1
# {'remainingOverageTime': 60, 'step': 2, 'geese': [[39], [30], [28, 27], [58]], 'food': [59, 41], 'index': 0}
# 100
# False
# {}
# Goose Collision: NORTH
# step : 2
# {'remainingOverageTime': 60, 'step': 3, 'geese': [[], [41, 30], [17, 28], [59, 58]], 'food': [49, 14], 'index': 0}
# 0
# True
# {}
# step : 3
# {'remainingOverageTime': 60, 'step': 1, 'geese': [[41], [20], [28], [65]], 'food': [50, 47], 'index': 0}
# 201
# False
# {}
# step : 4
# {'remainingOverageTime': 60, 'step': 2, 'geese': [[30], [31], [39], [54]], 'food': [50, 47], 'index': 0}
# 100
# False
# {}
# step : 5
# {'remainingOverageTime': 60, 'step': 3, 'geese': [[19], [42], [50, 39], [44]], 'food': [47, 66], 'index': 0}
# 100
# False
# {}
# step : 6
# {'remainingOverageTime': 60, 'step': 4, 'geese': [[8], [53], [49, 50], [55]], 'food': [47, 66], 'index': 0}
# 100
# False
# ...
